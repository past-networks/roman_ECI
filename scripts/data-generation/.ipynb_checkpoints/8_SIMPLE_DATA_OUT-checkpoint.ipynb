# %% [markdown]
# # 8. Extraction of the dataset
#
# *AIM:* Exptraction of the data in multiple formats for external use.

# %% [markdown]
# ## Data:
#
# ### IN:
#
# 1) Inscriptions with occupational data, urban contexts, industry types `LIST_occupsorgs_industry.parquet`
#
# ### OUT:
#
# 1) Simplified (only to necessary attributes) inscriptions with occupational data, urban contexts, industry types `LIST_occupsorgs_industry_simple_20231206.parquet`

# %% [markdown]
# # Requirements

# %%
import pandas as pd
pd.set_option('display.max_columns', 200)
import numpy as np
import fiona

import geopandas as gpd

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import json

from nltk import ngrams

import seaborn as sns
import geoplot as gplt

import warnings
warnings.filterwarnings('ignore')

import sddk
import tempun

# %%
# global parameters for plots
#plt.style.use("seaborn-white")
plt.style.use("seaborn-v0_8-white")
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams['font.size'] = 8

def save_figure(fig, fig_name):
    #each figure to be saved in four different versions
    fig.savefig("../../figures/" + fig_name + ".tiff")
    fig.savefig("../../figures/" + fig_name + ".svg")
    fig.savefig("../../figures/" + fig_name + ".png")
    s.write_file(figpath + fig_name + ".eps", fig)
    s.write_file(figpath + fig_name + ".png", fig)

# %%
# to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:
# but you can have yours stored locally on your computer and read it in directly
s = sddk.cloudSession("sciencedata.dk", "./PSNP_shared/lat_socdiv/", "648560@au.dk")
figpath = "./PSNP_shared/lat_socdiv/"
# Out:
# Your ScienceData username (e.g. '123456@au.dk'):  648560@au.dk
# Your ScienceData password:  ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/./PSNP_shared/lat_socdiv//

# %% [markdown]
# # Import the dataset

# %%
LIST = gpd.read_parquet("../../data/large_data/LIST_occupsorgs_industry.parquet")
LIST.head(3)
# Out:
#    LIST-ID        EDCS-ID    EDH-ID                          trismegistos_uri  \
# 0   445464  EDCS-24900077  HD056163  https://www.trismegistos.org/text/177366
# 1   445465  EDCS-03700724  HD052964  https://www.trismegistos.org/text/121715
# 2   445466  EDCS-13800065  HD017714  https://www.trismegistos.org/text/177100
#
#   pleiades_id                                      transcription  \
# 0      570485  Q(uinto) Caecilio C(ai) f(ilio) Metelo / imper...
# 1      531064  Fortissimo et piis/simo Caesari d(omino) n(ost...
# 2      570049  Italicei / quei Aegei negotiantur / P(ublium) ...
#
#                                          inscription  \
# 0  Q(uinto) Caecilio C(ai) f(ilio) Metel(l)o / im...
# 1  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 2  Italicei / quei Aegei negotiantur / P(ublium) ...
#
#                              clean_text_conservative  \
# 0  Q Caecilio C f Metelo imperatori Italici quei ...
# 1  Fortissimo et piissimo Caesari d n Gal Val P F...
# 2  Italicei quei Aegei negotiantur P Rutilium P f...
#
#                     clean_text_interpretive_sentence  \
# 0  Quinto Caecilio Cai filio Metelo imperatori It...
# 1  Fortissimo et piissimo Caesari domino nostro G...
# 2  Italicei quei Aegei negotiantur Publium Rutili...
#
#                         clean_text_interpretive_word  \
# 0  Quinto Caecilio Cai filio Metelo imperatori It...
# 1  Fortissimo et piissimo Caesari domino nostro G...
# 2  Italicei quei Aegei negotiantur Publium Rutili...
#
#                    clean_text_interpretive_word_EDCS  \
# 0  Quinto Caecilio Cai filio Metello imperatori I...
# 1  Fortissimo et Piissimo Caesari domino nostro G...
# 2  Italicei quei Aegei negotiantur Publium Rutili...
#
#                                      diplomatic_text province  \
# 0  Q CAECILIO C F METELO / IMPERATORI ITALICI / Q...   Achaia
# 1  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...   Achaia
# 2  ITALICEI / QVEI AEGEI NEGOTIANTVR / P RVTILIVM...   Achaia
#
#                             place        inscr_type  \
# 0   Agia Triada / Merbaka / Midea  tituli honorarii
# 1      Agios Athanasios / Photike  tituli honorarii
# 2  Aigio / Egio / Aiyion / Aegeum  tituli honorarii
#
#                                      status_notation    inscr_process  \
# 0  officium/professio, ordo senatorius, tria nomi...             None
# 1       Augusti/Augustae, ordo equester, tria nomina  litterae erasae
# 2  officium/professio, ordo senatorius, tria nomi...             None
#
#                                               status  \
# 0  officium/professio;  ordo senatorius;  tituli ...
# 1  Augusti/Augustae;  litterae erasae;  ordo eque...
# 2  officium/professio;  ordo senatorius;  tituli ...
#
#                                         partner_link last_update letter_size  \
# 0  http://db.edcs.eu/epigr/partner.php?s_language...  2011-11-11        None
# 1  http://db.edcs.eu/epigr/partner.php?s_language...  2014-09-16    3-5.3 cm
# 2  http://db.edcs.eu/epigr/partner.php?s_language...  2011-03-29  3.5-3.7 cm
#
#      type_of_inscription         work_status  year_of_find present_location  \
# 0  honorific inscription            no image           NaN             None
# 1  honorific inscription  checked with photo           NaN    Fragma Kalama
# 2     votive inscription  checked with photo           NaN             None
#
#                                         text_edition support_objecttype  \
# 0  \n Quinto Caecilio Cai filio Metelo imperatori...               None
# 1  \n Fortissimo et piissimo Caesari domino nostr...                 57
# 2  \n Italicei quei Aegei negotiantur Publium Rut...                257
#
#   support_material support_decoration keywords_term  \
# 0             None               1000            69
# 1             None               1000            69
# 2             None               1000           372
#
#                                               people  \
# 0  [{'age: days': None, 'age: hours': None, 'age:...
# 1  [{'age: days': None, 'age: hours': None, 'age:...
# 2  [{'age: days': None, 'age: hours': None, 'age:...
#
#   type_of_inscription_clean  type_of_inscription_certainty  height_cm  \
# 0     honorific inscription                          False        NaN
# 1     honorific inscription                          False       99.0
# 2        votive inscription                          False       58.0
#
#    width_cm  depth_cm material_clean type_of_monument_clean  \
# 0       NaN       NaN           NULL                   NULL
# 1      67.0      67.0           NULL            statue base
# 2      61.0      16.0           NULL                 tabula
#
#    type_of_monument_certainty province_label_clean  province_label_certainty  \
# 0                       False               Achaia                     False
# 1                       False               Epirus                     False
# 2                       False               Achaia                     False
#
#   country_clean  country_certainty findspot_ancient_clean  \
# 0        Greece              False                  Midea
# 1        Greece              False                Photike
# 2        Greece              False                 Aegeum
#
#    findspot_ancient_certainty modern_region_clean  modern_region_certainty  \
# 0                       False        Pelopónissos                    False
# 1                       False             Ípeiros                    False
# 2                       False       Dytikí Elláda                    False
#
#   findspot_modern_clean  findspot_modern_certainty      findspot_clean  \
# 0                Midhéa                      False                NULL
# 1            Paramythía                      False  {Agios Athanasios}
# 2                Aígion                      False                NULL
#
#    findspot_certainty language_EDCS  raw_dating  not_after  not_before  \
# 0               False          None  -68 to -68      -68.0       -68.0
# 1               False          None  309 to 313      313.0       309.0
# 2               False          None  -74 to -74      -74.0       -74.0
#
#    Longitude  Latitude  is_geotemporal               geometry  is_within_RE  \
# 0    22.8412   37.6498            True  POINT (22.841 37.650)          True
# 1    20.7668   39.4512            True  POINT (20.767 39.451)          True
# 2    22.0845   38.2487            True  POINT (22.084 38.249)          True
#
#   urban_context urban_context_city  urban_context_pop_est  \
# 0         rural               None                    NaN
# 1         rural               None                    NaN
# 2         small             Aegium                 1000.0
#
#   type_of_inscription_auto  type_of_inscription_auto_prob occups  occups_N  \
# 0    honorific inscription                            1.0     []         0
# 1    honorific inscription                            1.0     []         0
# 2       votive inscription                            1.0     []         0
#
#   organizations  organizations_N  is_western large_city_ID  \
# 0            []                0       False            13
# 1            []                0       False            65
# 2            []                0       False            92
#
#            large_city_geo  large_city_dist medium_city_ID  \
# 0  [22.719769, 37.631278]         10912.81             85
# 1  [20.733395, 39.026505]         47237.78              7
# 2    [22.726044, 37.9799]         63682.52             24
#
#           medium_city_geo  medium_city_dist small_city_ID  \
# 0  [22.641069, 37.831664]          26806.86            36
# 1        [20.987, 39.158]          37687.28            31
# 2  [22.044647, 37.885611]          40453.51             6
#
#            small_city_geo  small_city_dist urban_context_alt occups_cats
# 0  [23.132244, 37.626573]         25817.21             rural          []
# 1  [20.787767, 39.546432]         10725.84             rural          []
# 2  [22.081952, 38.252707]           497.57             small          []

# %% [markdown]
# # Simplify the dataset

# %%
# making sure the data exists and loaded properly, printing out all the attribute names
print(LIST.columns.tolist())
# Out:
# ['LIST-ID', 'EDCS-ID', 'EDH-ID', 'trismegistos_uri', 'pleiades_id', 'transcription', 'inscription', 'clean_text_conservative', 'clean_text_interpretive_sentence', 'clean_text_interpretive_word', 'clean_text_interpretive_word_EDCS', 'diplomatic_text', 'province', 'place', 'inscr_type', 'status_notation', 'inscr_process', 'status', 'partner_link', 'last_update', 'letter_size', 'type_of_inscription', 'work_status', 'year_of_find', 'present_location', 'text_edition', 'support_objecttype', 'support_material', 'support_decoration', 'keywords_term', 'people', 'type_of_inscription_clean', 'type_of_inscription_certainty', 'height_cm', 'width_cm', 'depth_cm', 'material_clean', 'type_of_monument_clean', 'type_of_monument_certainty', 'province_label_clean', 'province_label_certainty', 'country_clean', 'country_certainty', 'findspot_ancient_clean', 'findspot_ancient_certainty', 'modern_region_clean', 'modern_region_certainty', 'findspot_modern_clean', 'findspot_modern_certainty', 'findspot_clean', 'findspot_certainty', 'language_EDCS', 'raw_dating', 'not_after', 'not_before', 'Longitude', 'Latitude', 'is_geotemporal', 'geometry', 'is_within_RE', 'urban_context', 'urban_context_city', 'urban_context_pop_est', 'type_of_inscription_auto', 'type_of_inscription_auto_prob', 'occups', 'occups_N', 'organizations', 'organizations_N', 'is_western', 'large_city_ID', 'large_city_geo', 'large_city_dist', 'medium_city_ID', 'medium_city_geo', 'medium_city_dist', 'small_city_ID', 'small_city_geo', 'small_city_dist', 'urban_context_alt', 'occups_cats']

# %%
LISTsimple = LIST[['LIST-ID', 'EDCS-ID', 'EDH-ID',
                   'Longitude', 'Latitude', 'geometry',
                   'urban_context', 'urban_context_city', 'urban_context_pop_est', 'urban_context_alt',
                   'occups', 'occups_N','occups_cats',
                   'clean_text_interpretive_word', 'type_of_inscription_auto']]

# %%
LISTsimple
# Out:
#         LIST-ID        EDCS-ID    EDH-ID  Longitude   Latitude  \
# 0        445464  EDCS-24900077  HD056163  22.841200  37.649800
# 1        445465  EDCS-03700724  HD052964  20.766800  39.451200
# 2        445466  EDCS-13800065  HD017714  22.084500  38.248700
# 3        445467  EDCS-03300852  HD051000  22.417100  37.431900
# 4        445468  EDCS-28500283  HD021396  22.420877  37.454501
# ...         ...            ...       ...        ...        ...
# 511968   445459  EDCS-10700071      None  13.026040  46.461796
# 511969   445460  EDCS-10700072      None  13.026040  46.461796
# 511970   445461  EDCS-10700073      None  13.026040  46.461796
# 511971   445462  EDCS-10700074      None  13.026040  46.461796
# 511972   445463  EDCS-10700076      None  13.026040  46.461796
#
#                      geometry urban_context urban_context_city  \
# 0       POINT (22.841 37.650)         rural               None
# 1       POINT (20.767 39.451)         rural               None
# 2       POINT (22.084 38.249)         small             Aegium
# 3       POINT (22.417 37.432)         large              Tegea
# 4       POINT (22.421 37.455)         large              Tegea
# ...                       ...           ...                ...
# 511968  POINT (13.026 46.462)         small    Iulium Carnicum
# 511969  POINT (13.026 46.462)         small    Iulium Carnicum
# 511970  POINT (13.026 46.462)         small    Iulium Carnicum
# 511971  POINT (13.026 46.462)         small    Iulium Carnicum
# 511972  POINT (13.026 46.462)         small    Iulium Carnicum
#
#         urban_context_pop_est urban_context_alt occups  occups_N occups_cats  \
# 0                         NaN             rural     []         0          []
# 1                         NaN             rural     []         0          []
# 2                      1000.0             small     []         0          []
# 3                     46362.0             large     []         0          []
# 4                     46362.0             large     []         0          []
# ...                       ...               ...    ...       ...         ...
# 511968                 1000.0             small     []         0          []
# 511969                 1000.0             small     []         0          []
# 511970                 1000.0             small     []         0          []
# 511971                 1000.0             small     []         0          []
# 511972                 1000.0             small     []         0          []
#
#                              clean_text_interpretive_word  \
# 0       Quinto Caecilio Cai filio Metelo imperatori It...
# 1       Fortissimo et piissimo Caesari domino nostro G...
# 2       Italicei quei Aegei negotiantur Publium Rutili...
# 3       Imperatori Caesari Marco Annio Floriano Pio Fe...
# 4       Tiberius Claudius Caesar Augustus Germanicus p...
# ...                                                   ...
# 511968                                              ACLAI
# 511969                                               IN P
# 511970                                                RIC
# 511971                                        ius Cai s L
# 511972  Vigilius et Dominica cum suis fecerunt pedes C...
#
#           type_of_inscription_auto
# 0            honorific inscription
# 1            honorific inscription
# 2               votive inscription
# 3                mile-/leaguestone
# 4         public legal inscription
# ...                            ...
# 511968  identification inscription
# 511969  identification inscription
# 511970  identification inscription
# 511971  identification inscription
# 511972                        None
#
# [511973 rows x 15 columns]

# %% [markdown]
# # Save the dataset in multiple formats

# %% [markdown]
# ## JSON

# %%
# to json on SDDK - DOES NOT WORK

#s.write_file("../data/large_data/LIST_occupsorgs_industry_simple_20231206.json", LISTsimple)
s.write_file("LIST_occupsorgs_industry_simple_20231206.json", LISTsimple)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 # to json on SDDK - DOES NOT WORK
#       2
#       3 #s.write_file("../data/large_data/LIST_occupsorgs_industry_simple_20231206.json", LISTsimple)
# ----> 4 s.write_file("LIST_occupsorgs_industry_simple_20231206.json", LISTsimple)
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/sddk/__init__.py:253, in cloudSession.write_file(self, path_and_filename, python_object)
#     251 approved_name = self.check_filename(path_and_filename)
#     252 file_ending = approved_name.rpartition(".")[2]
# --> 253 data_processed = make_data_from_object(python_object, file_ending)
#     254 try:
#     255     if not approved_name.rpartition(".")[2] in ["txt", "json", "geojson", "csv", "png", "feather", "parquet"]:
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/sddk/__init__.py:37, in make_data_from_object(python_object, file_ending)
#      35 if file_ending == "json":
#      36     with open('temp.json', 'w', encoding='utf-8') as file:
# ---> 37         python_object.to_json(file, force_ascii=False)
#      38     return (type(python_object), open("temp.json", "rb"))
#      39 if file_ending == "geojson":
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/geopandas/geodataframe.py:812, in GeoDataFrame.to_json(self, na, show_bbox, drop_id, to_wgs84, **kwargs)
#     809 else:
#     810     df = self
# --> 812 geo = df._to_geo(na=na, show_bbox=show_bbox, drop_id=drop_id)
#     814 # if the geometry is not in WGS84, include CRS in the JSON
#     815 if df.crs is not None and not df.crs.equals("epsg:4326"):
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/geopandas/geodataframe.py:982, in GeoDataFrame._to_geo(self, **kwargs)
#     974 def _to_geo(self, **kwargs):
#     975     """
#     976     Returns a python feature collection (i.e. the geointerface)
#     977     representation of the GeoDataFrame.
#     978
#     979     """
#     980     geo = {
#     981         "type": "FeatureCollection",
# --> 982         "features": list(self.iterfeatures(**kwargs)),
#     983     }
#     985     if kwargs.get("show_bbox", False):
#     986         geo["bbox"] = tuple(self.total_bounds)
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/geopandas/geodataframe.py:906, in GeoDataFrame.iterfeatures(self, na, show_bbox, drop_id)
#     867         """
#     868         Returns an iterator that yields feature dictionaries that comply with
#     869         __geo_interface__
#    (...)
#     903 'type': 'Point', 'coordinates': (1.0, 2.0)}}
#     904         """
#     905         if na not in ["null", "drop", "keep"]:
# --> 906             raise ValueError("Unknown na method {0}".format(na))
#     908         if self._geometry_column_name not in self:
#     909             raise AttributeError(
#     910                 "No geometry data set (expected in"
#     911                 " column '%s')." % self._geometry_column_name
#     912             )
#
# ValueError: Unknown na method <_io.TextIOWrapper name='temp.json' mode='w' encoding='utf-8'>

# %%
# to json locally - DOES not work TypeError: Object of type GeoDataFrame is not JSON serializable

with open('../../data/large_data/LIST_occupsorgs_industry_simple_20231206.geojson', 'w') as f:
    json.dump(LISTsimple, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 # to json locally
#       3 with open('../../data/large_data/LIST_occupsorgs_industry_simple_20231206.geojson', 'w') as f:
# ----> 4     json.dump(LISTsimple, f)
#
# File /usr/lib/python3.10/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File /usr/lib/python3.10/json/encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File /usr/lib/python3.10/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type GeoDataFrame is not JSON serializable

# %% [markdown]
# ## GEOJSON

# %%
# to geojson on SDDK

#s.write_file("data_public/LIST_occupsorgs_industry_simple_20231206.geojson", LISTsimple)

# %%
# to geojson locally

LISTsimple.to_file("../../data/large_data/LIST_occupsorgs_industry_simple_20231206.geojson", driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # to geojson locally
# ----> 3 LISTsimple.to_file("../../data/large_data/LIST_occupsorgs_industry_simple_20231206.geojson", driver='GeoJSON')
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1264, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1173 """Write the ``GeoDataFrame`` to a file.
#    1174
#    1175 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1260
#    1261 """
#    1262 from geopandas.io.file import _to_file
# -> 1264 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/geopandas/io/file.py:612, in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     609     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     611 if engine == "fiona":
# --> 612     _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     613 elif engine == "pyogrio":
#     614     _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/geopandas/io/file.py:641, in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     637     crs_wkt = crs.to_wkt("WKT1_GDAL")
#     638 with fiona.open(
#     639     filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     640 ) as colxn:
# --> 641     colxn.writerecords(df.iterfeatures())
#
# File ~/Github/latin_socdiv/latinsocdiv_venv/lib/python3.10/site-packages/fiona/collection.py:558, in Collection.writerecords(self, records)
#     556 if self.mode not in ("a", "w"):
#     557     raise OSError("collection not open for writing")
# --> 558 self.session.writerecs(records, self)
#     559 self._len = self.session.get_length()
#     560 self._bounds = None
#
# File fiona/ogrext.pyx:1409, in fiona.ogrext.WritingSession.writerecs()
#
# File fiona/ogrext.pyx:514, in fiona.ogrext.OGRFeatureBuilder.build()
#
# ValueError: Invalid field type <class 'numpy.ndarray'>

# %% [markdown]
# ## Parquet

# %%
LISTsimple.to_parquet("../../data/large_data/LIST_occupsorgs_industry_simple_20231206.parquet")

# %% [markdown]
# # Loading the data back to make sure it works

# %%
#public_folder_code = "b963a7045f36c28cccce56df9279e969" 

#LISTjson = s.read_file("LIST_occupsorgs_industry_simple_20231206.json" , "df",  public_folder_code)

#LISTjson.head(3)
# Out:
# file import failed. JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %%
#LISTgeojson = gpd.read_file("../../data/large_data/LIST_occupsorgs_industry_simple_20231206.geojson", driver="GeoJSON")
#LISTgeojson.head(3)

# %%
LISTparquet = gpd.read_parquet("../../data/large_data/LIST_occupsorgs_industry_simple_20231206.parquet")
LISTparquet.head(3)
# Out:
#    LIST-ID        EDCS-ID    EDH-ID  Longitude  Latitude  \
# 0   445464  EDCS-24900077  HD056163    22.8412   37.6498
# 1   445465  EDCS-03700724  HD052964    20.7668   39.4512
# 2   445466  EDCS-13800065  HD017714    22.0845   38.2487
#
#                 geometry urban_context urban_context_city  \
# 0  POINT (22.841 37.650)         rural               None
# 1  POINT (20.767 39.451)         rural               None
# 2  POINT (22.084 38.249)         small             Aegium
#
#    urban_context_pop_est urban_context_alt occups  occups_N occups_cats  \
# 0                    NaN             rural     []         0          []
# 1                    NaN             rural     []         0          []
# 2                 1000.0             small     []         0          []
#
#                         clean_text_interpretive_word type_of_inscription_auto
# 0  Quinto Caecilio Cai filio Metelo imperatori It...    honorific inscription
# 1  Fortissimo et piissimo Caesari domino nostro G...    honorific inscription
# 2  Italicei quei Aegei negotiantur Publium Rutili...       votive inscription
