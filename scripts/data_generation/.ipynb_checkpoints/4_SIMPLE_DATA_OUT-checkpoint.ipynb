# %% [markdown]
# ### 4. Extraction of the dataset
#
# *AIM:* Exptraction of the data in multiple formats for external use.

# %% [markdown]
# ## Data:
#
# **IN**:
#
# 1) Inscriptions with occupational data, urban contexts, industry types `LIST_occups.parquet`
#
# **OUT**:
#
# 1) Simplified (only to necessary attributes) inscriptions with occupational data, urban contexts, industry types
#    * `LIST_occups_simple.parquet` with geometries
#    * `LIST_occups_simple.json` without geometries

# %% [markdown]
# # Requirements

# %%
import pandas as pd
pd.set_option('display.max_columns', 200)
import numpy as np
import fiona
import os

import geopandas as gpd

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import json

from nltk import ngrams

import seaborn as sns
import geoplot as gplt

import warnings
warnings.filterwarnings('ignore')

import sddk
import tempun

# %% [markdown]
# # Import the dataset

# %%
# get working directory
os.getcwd()
# Out:
# '/home/au648560/Github/roman_ECI/scripts/data_generation'

# %%
LIST = gpd.read_parquet("../../data/large_data/LIST_occups.parquet")
LIST.head(3)
# Out:
#         LIST-ID        EDCS-ID    EDH-ID  \
# 445463   445464  EDCS-24900077  HD056163
# 445464   445465  EDCS-03700724  HD052964
# 445465   445466  EDCS-13800065  HD017714
#
#                                 trismegistos_uri pleiades_id  \
# 445463  https://www.trismegistos.org/text/177366      570485
# 445464  https://www.trismegistos.org/text/121715      531064
# 445465  https://www.trismegistos.org/text/177100      570049
#
#                                             transcription  \
# 445463  Q(uinto) Caecilio C(ai) f(ilio) Metelo / imper...
# 445464  Fortissimo et piis/simo Caesari d(omino) n(ost...
# 445465  Italicei / quei Aegei negotiantur / P(ublium) ...
#
#                                               inscription  \
# 445463  Q(uinto) Caecilio C(ai) f(ilio) Metel(l)o / im...
# 445464  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 445465  Italicei / quei Aegei negotiantur / P(ublium) ...
#
#                                   clean_text_conservative  \
# 445463  Q Caecilio C f Metelo imperatori Italici quei ...
# 445464  Fortissimo et piissimo Caesari d n Gal Val P F...
# 445465  Italicei quei Aegei negotiantur P Rutilium P f...
#
#                          clean_text_interpretive_sentence  \
# 445463  Quinto Caecilio Cai filio Metelo imperatori It...
# 445464  Fortissimo et piissimo Caesari domino nostro G...
# 445465  Italicei quei Aegei negotiantur Publium Rutili...
#
#                              clean_text_interpretive_word  \
# 445463  Quinto Caecilio Cai filio Metelo imperatori It...
# 445464  Fortissimo et piissimo Caesari domino nostro G...
# 445465  Italicei quei Aegei negotiantur Publium Rutili...
#
#                         clean_text_interpretive_word_EDCS  \
# 445463  Quinto Caecilio Cai filio Metello imperatori I...
# 445464  Fortissimo et Piissimo Caesari domino nostro G...
# 445465  Italicei quei Aegei negotiantur Publium Rutili...
#
#                                           diplomatic_text province  \
# 445463  Q CAECILIO C F METELO / IMPERATORI ITALICI / Q...   Achaia
# 445464  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...   Achaia
# 445465  ITALICEI / QVEI AEGEI NEGOTIANTVR / P RVTILIVM...   Achaia
#
#                                  place        inscr_type  \
# 445463   Agia Triada / Merbaka / Midea  tituli honorarii
# 445464      Agios Athanasios / Photike  tituli honorarii
# 445465  Aigio / Egio / Aiyion / Aegeum  tituli honorarii
#
#                                           status_notation    inscr_process  \
# 445463  officium/professio, ordo senatorius, tria nomi...             None
# 445464       Augusti/Augustae, ordo equester, tria nomina  litterae erasae
# 445465  officium/professio, ordo senatorius, tria nomi...             None
#
#                                                    status  \
# 445463  officium/professio;  ordo senatorius;  tituli ...
# 445464  Augusti/Augustae;  litterae erasae;  ordo eque...
# 445465  officium/professio;  ordo senatorius;  tituli ...
#
#                                              partner_link last_update  \
# 445463  http://db.edcs.eu/epigr/partner.php?s_language...  2011-11-11
# 445464  http://db.edcs.eu/epigr/partner.php?s_language...  2014-09-16
# 445465  http://db.edcs.eu/epigr/partner.php?s_language...  2011-03-29
#
#        letter_size    type_of_inscription         work_status  year_of_find  \
# 445463        None  honorific inscription            no image           NaN
# 445464    3-5.3 cm  honorific inscription  checked with photo           NaN
# 445465  3.5-3.7 cm     votive inscription  checked with photo           NaN
#
#        present_location                                       text_edition  \
# 445463             None  \n Quinto Caecilio Cai filio Metelo imperatori...
# 445464    Fragma Kalama  \n Fortissimo et piissimo Caesari domino nostr...
# 445465             None  \n Italicei quei Aegei negotiantur Publium Rut...
#
#        support_objecttype support_material support_decoration keywords_term  \
# 445463               None             None               1000            69
# 445464                 57             None               1000            69
# 445465                257             None               1000           372
#
#                                                    people  \
# 445463  [{'age: days': None, 'age: hours': None, 'age:...
# 445464  [{'age: days': None, 'age: hours': None, 'age:...
# 445465  [{'age: days': None, 'age: hours': None, 'age:...
#
#        type_of_inscription_clean  type_of_inscription_certainty  height_cm  \
# 445463     honorific inscription                          False        NaN
# 445464     honorific inscription                          False       99.0
# 445465        votive inscription                          False       58.0
#
#         width_cm  depth_cm material_clean type_of_monument_clean  \
# 445463       NaN       NaN           NULL                   NULL
# 445464      67.0      67.0           NULL            statue base
# 445465      61.0      16.0           NULL                 tabula
#
#         type_of_monument_certainty province_label_clean  \
# 445463                       False               Achaia
# 445464                       False               Epirus
# 445465                       False               Achaia
#
#         province_label_certainty country_clean  country_certainty  \
# 445463                     False        Greece              False
# 445464                     False        Greece              False
# 445465                     False        Greece              False
#
#        findspot_ancient_clean  findspot_ancient_certainty modern_region_clean  \
# 445463                  Midea                       False        Pelopónissos
# 445464                Photike                       False             Ípeiros
# 445465                 Aegeum                       False       Dytikí Elláda
#
#         modern_region_certainty findspot_modern_clean  \
# 445463                    False                Midhéa
# 445464                    False            Paramythía
# 445465                    False                Aígion
#
#         findspot_modern_certainty      findspot_clean  findspot_certainty  \
# 445463                      False                NULL               False
# 445464                      False  {Agios Athanasios}               False
# 445465                      False                NULL               False
#
#        language_EDCS  raw_dating  not_after  not_before  Longitude  Latitude  \
# 445463          None  -68 to -68      -68.0       -68.0    22.8412   37.6498
# 445464          None  309 to 313      313.0       309.0    20.7668   39.4512
# 445465          None  -74 to -74      -74.0       -74.0    22.0845   38.2487
#
#         is_geotemporal               geometry  is_within_RE urban_context  \
# 445463            True  POINT (22.841 37.650)          True         rural
# 445464            True  POINT (20.767 39.451)          True         rural
# 445465            True  POINT (22.084 38.249)          True         small
#
#        urban_context_city  urban_context_pop_est type_of_inscription_auto  \
# 445463               None                    NaN    honorific inscription
# 445464               None                    NaN    honorific inscription
# 445465             Aegium                 1000.0       votive inscription
#
#         type_of_inscription_auto_prob occups  occups_N occups_cats_Harris  \
# 445463                            1.0     []         0                 []
# 445464                            1.0     []         0                 []
# 445465                            1.0     []         0                 []
#
#        occups_cats_HISCO
# 445463                []
# 445464                []
# 445465                []

# %% [markdown]
# # Simplify the dataset

# %%
# making sure the data exists and loaded properly, printing out all the attribute names
print(LIST.columns.tolist())
# Out:
# ['LIST-ID', 'EDCS-ID', 'EDH-ID', 'trismegistos_uri', 'pleiades_id', 'transcription', 'inscription', 'clean_text_conservative', 'clean_text_interpretive_sentence', 'clean_text_interpretive_word', 'clean_text_interpretive_word_EDCS', 'diplomatic_text', 'province', 'place', 'inscr_type', 'status_notation', 'inscr_process', 'status', 'partner_link', 'last_update', 'letter_size', 'type_of_inscription', 'work_status', 'year_of_find', 'present_location', 'text_edition', 'support_objecttype', 'support_material', 'support_decoration', 'keywords_term', 'people', 'type_of_inscription_clean', 'type_of_inscription_certainty', 'height_cm', 'width_cm', 'depth_cm', 'material_clean', 'type_of_monument_clean', 'type_of_monument_certainty', 'province_label_clean', 'province_label_certainty', 'country_clean', 'country_certainty', 'findspot_ancient_clean', 'findspot_ancient_certainty', 'modern_region_clean', 'modern_region_certainty', 'findspot_modern_clean', 'findspot_modern_certainty', 'findspot_clean', 'findspot_certainty', 'language_EDCS', 'raw_dating', 'not_after', 'not_before', 'Longitude', 'Latitude', 'is_geotemporal', 'geometry', 'is_within_RE', 'urban_context', 'urban_context_city', 'urban_context_pop_est', 'type_of_inscription_auto', 'type_of_inscription_auto_prob', 'occups', 'occups_N', 'occups_cats_Harris', 'occups_cats_HISCO']

# %%
LISTsimple = LIST[['LIST-ID', 
                       'Longitude', 
                       'Latitude', 
                       'occups', 
                       'occups_N',
                       'type_of_inscription_auto',
                       'occups_cats_Harris', 
                       'occups_cats_HISCO',
                       'clean_text_interpretive_word',
                       'not_before',
                       'not_after']]

# %%
LISTsimple
# Out:
#         LIST-ID  Longitude   Latitude occups  occups_N  \
# 445463   445464  22.841200  37.649800     []         0
# 445464   445465  20.766800  39.451200     []         0
# 445465   445466  22.084500  38.248700     []         0
# 445466   445467  22.417100  37.431900     []         0
# 445467   445468  22.420877  37.454501     []         0
# ...         ...        ...        ...    ...       ...
# 445458   445459  13.026040  46.461796     []         0
# 445459   445460  13.026040  46.461796     []         0
# 445460   445461  13.026040  46.461796     []         0
# 445461   445462  13.026040  46.461796     []         0
# 445462   445463  13.026040  46.461796     []         0
#
#           type_of_inscription_auto occups_cats_Harris occups_cats_HISCO  \
# 445463       honorific inscription                 []                []
# 445464       honorific inscription                 []                []
# 445465          votive inscription                 []                []
# 445466           mile-/leaguestone                 []                []
# 445467    public legal inscription                 []                []
# ...                            ...                ...               ...
# 445458  identification inscription                 []                []
# 445459  identification inscription                 []                []
# 445460  identification inscription                 []                []
# 445461  identification inscription                 []                []
# 445462                        None                 []                []
#
#                              clean_text_interpretive_word  not_before  \
# 445463  Quinto Caecilio Cai filio Metelo imperatori It...       -68.0
# 445464  Fortissimo et piissimo Caesari domino nostro G...       309.0
# 445465  Italicei quei Aegei negotiantur Publium Rutili...       -74.0
# 445466  Imperatori Caesari Marco Annio Floriano Pio Fe...       276.0
# 445467  Tiberius Claudius Caesar Augustus Germanicus p...        49.0
# ...                                                   ...         ...
# 445458                                              ACLAI         1.0
# 445459                                               IN P         1.0
# 445460                                                RIC         1.0
# 445461                                        ius Cai s L       -25.0
# 445462  Vigilius et Dominica cum suis fecerunt pedes C...       351.0
#
#         not_after
# 445463      -68.0
# 445464      313.0
# 445465      -74.0
# 445466      282.0
# 445467       50.0
# ...           ...
# 445458      200.0
# 445459      200.0
# 445460      200.0
# 445461       25.0
# 445462      425.0
#
# [525870 rows x 11 columns]

# %% [markdown]
# # Save the dataset in multiple formats

# %% [markdown]
# ## JSON

# %%
# write to json locally 

pd.DataFrame(LISTsimple).to_json('../../data/large_data/LIST_occups_simple.json')

# %% [markdown]
# ## GEOJSON - does not work currently

# %%
# to geojson locally - does not currently work

#LISTsimple.to_file("../../data/large_data/LIST_occups_simple.geojson", driver='GeoJSON')

# %% [markdown]
# ## Parquet

# %%
# locally to parquet

LISTsimple.to_parquet("../../data/large_data/LIST_occups_simple.parquet")

# %% [markdown]
# # Loading the data back to make sure it works

# %%
# from local version
LISTjson = pd.read_json("../../data/large_data/LIST_occups_simple.json")
LISTjson.head(3)
# Out:
#         LIST-ID  Longitude  Latitude occups  occups_N  \
# 445463   445464    22.8412   37.6498     []         0
# 445464   445465    20.7668   39.4512     []         0
# 445465   445466    22.0845   38.2487     []         0
#
#        type_of_inscription_auto occups_cats_Harris occups_cats_HISCO  \
# 445463    honorific inscription                 []                []
# 445464    honorific inscription                 []                []
# 445465       votive inscription                 []                []
#
#                              clean_text_interpretive_word  not_before  \
# 445463  Quinto Caecilio Cai filio Metelo imperatori It...       -68.0
# 445464  Fortissimo et piissimo Caesari domino nostro G...       309.0
# 445465  Italicei quei Aegei negotiantur Publium Rutili...       -74.0
#
#         not_after
# 445463      -68.0
# 445464      313.0
# 445465      -74.0

# %%
#LISTgeojson = gpd.read_file("../../data/large_data/LIST_occupsorgs_industry_simple_20231206.geojson", driver="GeoJSON")
#LISTgeojson.head(3)

# %%
LISTparquet = pd.read_parquet("../../data/large_data/LIST_occups_simple.parquet")
LISTparquet.head(3)
# Out:
#         LIST-ID  Longitude  Latitude occups  occups_N  \
# 445463   445464    22.8412   37.6498     []         0
# 445464   445465    20.7668   39.4512     []         0
# 445465   445466    22.0845   38.2487     []         0
#
#        type_of_inscription_auto occups_cats_Harris occups_cats_HISCO  \
# 445463    honorific inscription                 []                []
# 445464    honorific inscription                 []                []
# 445465       votive inscription                 []                []
#
#                              clean_text_interpretive_word  not_before  \
# 445463  Quinto Caecilio Cai filio Metelo imperatori It...       -68.0
# 445464  Fortissimo et piissimo Caesari domino nostro G...       309.0
# 445465  Italicei quei Aegei negotiantur Publium Rutili...       -74.0
#
#         not_after
# 445463      -68.0
# 445464      313.0
# 445465      -74.0
